# %%
import xlrd
import time

# %%
loc = ("/home/sameen/Documents/blockchain/multi mining/temp.xlsx")
wb = xlrd.open_workbook(loc) 
sheet = wb.sheet_by_index(0) 

#region ={}
region0 =[]
region1=[]
region2=[]
region3=[]
region4=[]
region5=[]

#region3=[]
#print(region1)

# %%
start = time.time()
for i in range(sheet.nrows):
    tempp = sheet.cell_value(i,0)
    if len(tempp) < 16 :
        tempp = ' 283035966979891a185698dd9c043a1eac75918e'
    else:
        dec = int(sheet.cell_value(i,0), 16)
    reg = dec%6
    if reg == 0:
        region0.append(dec)
    elif reg == 1:
        region1.append(dec)
    elif reg == 2:
       region2.append(dec) 
    elif reg==3:
       region3.append(dec)
    elif reg==4:
       region4.append(dec)
    else:
        region5.append(dec)
    #region0.append(sheet.cell_value(i,0))
    print(i," ",reg) 
end = time.time()

print('Time: ',end-start )
print("Region 0:",len(region0))
print("Region 1:",len(region1))
print("Region 2:",len(region2))
print("Region 3:",len(region3))
print("Region 4:",len(region4))
print("Region 5:",len(region5))
# Out:
# 0   5
# 1   2
# 2   5
# 3   0
# 4   3
# 5   3
# 6   2
# 7   5
# 8   4
# 9   3
# 10   4
# 11   0
# 12   4
# 13   4
# 14   3
# 15   5
# 16   4
# 17   4
# 18   3
# 19   0
# 20   5
# 21   3
# 22   3
# 23   3
# 24   2
# 25   4
# 26   2
# 27   3
# 28   2
# 29   5
# 30   2
# 31   3
# 32   3
# 33   3
# 34   3
# 35   3
# 36   5
# 37   4
# 38   4
# 39   0
# 40   1
# 41   1
# 42   2
# 43   2
# 44   2
# 45   5
# 46   5
# 47   1
# 48   3
# 49   0
# 50   3
# 51   5
# 52   4
# 53   1
# 54   5
# 55   1
# 56   5
# 57   1
# 58   2
# 59   4
# 60   5
# 61   2
# 62   1
# 63   1
# 64   1
# 65   1
# 66   1
# 67   1
# 68   1
# 69   1
# 70   1
# 71   1
# 72   1
# 73   2
# 74   4
# 75   5
# 76   5
# 77   5
# 78   4
# 79   3
# 80   4
# 81   2
# 82   0
# 83   5
# 84   1
# 85   4
# 86   3
# 87   0
# 88   2
# 89   5
# 90   3
# 91   1
# 92   0
# 93   5
# 94   0
# 95   1
# 96   3
# 97   2
# 98   5
# 99   0
# 100   0
# 101   0
# 102   5
# 103   5
# 104   5
# 105   5
# 106   5
# 107   0
# 108   0
# 109   2
# 110   4
# ...
